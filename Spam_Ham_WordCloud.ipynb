# %%
import pandas as pd

# %%
df = pd.read_csv('/content/spam_or_ham.csv', encoding = "ISO-8859-1")

# %%
df.head
# Out:
# <bound method NDFrame.head of       Spam                                               Text
# 0        1  Last chance 2 claim ur Ã¥Â£150 worth of discou...
# 1        0         You still around? Looking to pick up later
# 2        0                          Have a good evening! Ttyl
# 3        0  Hi the way I was with u 2day, is the normal wa...
# 4        0  Pls clarify back if an open return ticket that...
# ...    ...                                                ...
# 5567     0               Ok lor Ã_ reaching then message me.
# 5568     0  its cool but tyler had to take off so we're go...
# 5569     0  if you aren't here in the next  &lt;#&gt;  hou...
# 5570     0                Yeah why not, is the gang all ready
# 5571     0  This pen thing is beyond a joke. Wont a Biro d...
#
# [5572 rows x 2 columns]>

# %%
df.shape
# Out:
# (5572, 2)

# %%
df.head(5)
# Out:
#    Spam                                               Text
# 0     1  Last chance 2 claim ur Ã¥Â£150 worth of discou...
# 1     0         You still around? Looking to pick up later
# 2     0                          Have a good evening! Ttyl
# 3     0  Hi the way I was with u 2day, is the normal wa...
# 4     0  Pls clarify back if an open return ticket that...

# %%
dfham= df[df.Spam ==1]

# %%
dfham.head(5)
# Out:
#     Spam                                               Text
# 0      1  Last chance 2 claim ur Ã¥Â£150 worth of discou...
# 22     1  Reminder: You have not downloaded the content ...
# 26     1  500 New Mobiles from 2004, MUST GO! Txt: NOKIA...
# 34     1  HOT LIVE FANTASIES call now 08707509020 Just 2...
# 45     1  all the lastest from Stereophonics, Marley, Di...

# %%
dfspam=df[df.Spam== 0]

# %%
dfspam.head(5)
# Out:
#    Spam                                               Text
# 1     0         You still around? Looking to pick up later
# 2     0                          Have a good evening! Ttyl
# 3     0  Hi the way I was with u 2day, is the normal wa...
# 4     0  Pls clarify back if an open return ticket that...
# 5     0  Tick, tick, tick .... Where are you ? I could ...

# %%
import wordcloud

# %%
import matplotlib.pyplot as plt

# %%
from wordcloud import WordCloud

# %%
dfspam.columns
# Out:
# Index(['Spam', 'Text'], dtype='object')

# %%
wordclouds = WordCloud(width = 800, height = 800,
                background_color ='white',
                min_font_size = 10).generate(str(dfspam.Text))

# %%
wordclouds

# %%
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordclouds)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
wordcloudh = WordCloud(width = 800, height = 800,
                background_color ='white',
                min_font_size = 10).generate(str(dfham.Text))

# %%
wordcloudh

# %%
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloudh)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
